# %% [markdown]
# <a href="https://colab.research.google.com/github/mcristinasanchez-ai/TFG_MATEM-TICAS_M.CristinaS-nchezTim-n/blob/main/PSO_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# w=0.5 c1=2.5 c2=0.1

# %%
import numpy as np
import pandas as pd

# 1. Funciones objetivo que vamos a minimizar
def sphere(x):
    return np.sum(x**2)

def schwefel_1(x):
    return np.sum(np.abs(x)) + np.prod(np.abs(x))

def schwefel_2(x):
    return np.sum([np.sum(x[:i+1])**2 for i in range(len(x))])

def schwefel_3(x):
    return np.max(np.abs(x))

def rosenbrock(x):
    return np.sum(100.0 * (x[1:] - x[:-1]**2.0)**2.0 + (x[:-1] - 1.0)**2.0)

def step(x):
    return np.sum(np.floor(x + 0.5)**2)

def quartic(x):
    return np.sum(np.arange(1, len(x) + 1) * (x**4)) + np.random.random()

def schwefel_4(x):
    return np.sum(-x * np.sin(np.sqrt(np.abs(x))))

def rastrigin(x):
    return np.sum(x**2 - 10 * np.cos(2 * np.pi * x) + 10)

def ackley(x):
    n = float(len(x))
    return -20 * np.exp(-0.2 * np.sqrt(np.sum(x**2) / n)) - np.exp(np.sum(np.cos(2 * np.pi * x)) / n) + 20 + np.exp(1)


funciones_prueba = {
    "Sphere": (sphere, -100, 100),
    "Schwefel 1": (schwefel_1, -10, 10),
    "Schwefel 2": (schwefel_2, -100, 100),
    "Schwefel 3": (schwefel_3, -100, 100),
    "Rosenbrock": (rosenbrock, -30, 30),
    "Step": (step, -100, 100),
    "Quartic": (quartic, -1.28, 1.28),
    "Schwefel 4": (schwefel_4, -500, 500),
    "Rastrigin": (rastrigin, -5.12, 5.12),
    "Ackley": (ackley, -32, 32)
}

# 2. Parámetros
num_particulas = 100 #cantidad de partículas en el espacio de búsqueda
num_iteraciones = 10000 #número pasos máximos que dara el enjambre de partículas en cada intento
dimension = 30 #espacio de búsqueda de 30 dimensiones
w = 0.5 #coeficiente de inercia que controla la tendencia de la partícula a seguir es su dirección actual
c1 = 2.5 #coeficiente cognitivo: cuanto confía la partícula en su propia experiencia
c2 = 0.1 #coeficiente social: cuanto influye el grupo en la partícula

num_ejecuciones = 10  #Numero de ejecuciones por cada función

#Se Almacenan los mejores resultados de cada ejecución
resultados_totales = {}

print("Iniciando optimizaciones...")

for nombre_funcion, (f, limite_inf, limite_sup) in funciones_prueba.items():
    print(f"\nEjecutando 10 veces para: {nombre_funcion}...")
    resultados_funcion = []  # Almacenenamos los 10 mejores resultados globales de esta función

    for ejecucion in range(num_ejecuciones):
        # 3. Inicialización
        posicion = np.random.uniform(limite_inf, limite_sup, (num_particulas, dimension)) #matriz donde se colocan las 100 partículas de forma aleatoria
        velocidad = np.zeros((num_particulas, dimension)) #se inicializa la velocidad a 0, las partículas inicialmente estan paradas

        pmejor_posicion = posicion.copy() #se guarda la mejor posición de la partícula
        pmejor_valor = np.array([f(p) for p in posicion]) #se calcula su valor
        gmejor_posicion = pmejor_posicion[np.argmin(pmejor_valor)].copy()  #se guarda la mejor posción del enjambre
        gmejor_valor = np.min(pmejor_valor) #se calcula su valor

        # 4. Bucle principal del algoritmo PSO
        for _ in range(num_iteraciones):
            #Se generan r1 y r2 aleatorios para posteriormente actualizar la velocidad
            #y la posición
            r1 = np.random.rand(num_particulas, dimension)
            r2 = np.random.rand(num_particulas, dimension)

            velocidad = (w * velocidad +
                         c1 * r1 * (pmejor_posicion - posicion) +
                         c2 * r2 * (gmejor_posicion - posicion))

            posicion += velocidad
            #Se usa np.clip para que las partículas no busquen en zonas no válidas
            #si se superan los límites permitidos
            posicion = np.clip(posicion, limite_inf, limite_sup)

            #Se evalúa la nueva posicón comoparando con la propia de la partícula
            #y con la del enjambre
            for i in range(num_particulas):
                valor_actual = f(posicion[i])
                if valor_actual < pmejor_valor[i]:
                    pmejor_valor[i] = valor_actual
                    pmejor_posicion[i] = posicion[i].copy()

                    if valor_actual < gmejor_valor:
                        gmejor_valor = valor_actual
                        gmejor_posicion = posicion[i].copy()

        resultados_funcion.append(gmejor_valor)
        print(f"  Ejecución {ejecucion + 1}: {gmejor_valor:.4e}")

    resultados_totales[nombre_funcion] = resultados_funcion


#CREAMOS LA TABLA CON LOS RESULTADOS DE CADA FUNCIÓN EN LAS 10 Iteraciones y
#Y CALCULAMOS LA MEDIA, MEDIANA Y VARIANZA


# 1. Se crea el Dataframe donde cada columna es una de las funciones de prueba y
#y cada fila son las ejecuiones
df_inicial = pd.DataFrame(resultados_totales)
df_inicial.index = [f"EJECUCIÓN {i+1}" for i in range(num_ejecuciones)]
df_final = df_inicial.copy()

# 2. Se calcula la media, mediana y varianza
df_final.loc['MEDIA'] = df_inicial.mean(axis=0)
df_final.loc['MEDIANA'] = df_inicial.median(axis=0)
df_final.loc['VARIANZA'] = df_inicial.var(axis=0)

# 3. Se muestan los resultados por pantalla y se guardan los resultados en la
#hoja de cáculo
print("\n" + "="*50)
print("TABLA COMPARATIVA FINAL")
print("="*50)
pd.set_option('display.float_format', lambda x: f'{x:.4e}')
print(df_final)
df_final.to_excel("Tabla comparativaPSO4.xlsx")
# Out:
# Iniciando optimizaciones...
#
# Ejecutando 10 veces para: Sphere...
#   Ejecución 1: 1.1494e+03
#   Ejecución 2: 1.1619e+03
#   Ejecución 3: 9.9544e+02
#   Ejecución 4: 6.0950e+02
#   Ejecución 5: 7.9652e+02
#   Ejecución 6: 5.0388e+02
#   Ejecución 7: 5.2536e+02
#   Ejecución 8: 3.1848e+02
#   Ejecución 9: 1.0579e+03
#   Ejecución 10: 3.4366e+02
#
# Ejecutando 10 veces para: Schwefel 1...
#   Ejecución 1: 1.5555e+01
#   Ejecución 2: 1.3350e+01
#   Ejecución 3: 1.7522e+01
#   Ejecución 4: 1.4668e+01
#   Ejecución 5: 1.6577e+01
#   Ejecución 6: 1.5573e+01
#   Ejecución 7: 1.4804e+01
#   Ejecución 8: 1.3489e+01
#   Ejecución 9: 1.5294e+01
#   Ejecución 10: 1.6687e+01
#
# Ejecutando 10 veces para: Schwefel 2...
#   Ejecución 1: 3.1999e+03
#   Ejecución 2: 4.4551e+03
#   Ejecución 3: 3.2653e+03
#   Ejecución 4: 4.7492e+03
#   Ejecución 5: 5.7842e+03
#   Ejecución 6: 5.3107e+03
#   Ejecución 7: 4.0613e+03
#   Ejecución 8: 4.8469e+03
#   Ejecución 9: 3.1447e+03
#   Ejecución 10: 1.4066e+03
#
# Ejecutando 10 veces para: Schwefel 3...
#   Ejecución 1: 1.5941e+01
#   Ejecución 2: 1.5605e+01
#   Ejecución 3: 1.2429e+01
#   Ejecución 4: 7.3298e+00
#   Ejecución 5: 1.6884e+01
#   Ejecución 6: 1.1481e+01
#   Ejecución 7: 1.6088e+01
#   Ejecución 8: 1.6157e+01
#   Ejecución 9: 1.4619e+01
#   Ejecución 10: 1.3742e+01
#
# Ejecutando 10 veces para: Rosenbrock...
#   Ejecución 1: 9.0286e+04
#   Ejecución 2: 3.3356e+04
#   Ejecución 3: 1.4327e+05
#   Ejecución 4: 4.5844e+04
#   Ejecución 5: 1.2796e+05
#   Ejecución 6: 6.5984e+04
#   Ejecución 7: 1.7594e+04
#   Ejecución 8: 1.4051e+05
#   Ejecución 9: 1.5205e+04
#   Ejecución 10: 4.1858e+04
#
# Ejecutando 10 veces para: Step...
#   Ejecución 1: 2.3100e+02
#   Ejecución 2: 2.9200e+02
#   Ejecución 3: 2.1300e+02
#   Ejecución 4: 4.0000e+02
#   Ejecución 5: 2.1200e+02
#   Ejecución 6: 2.4000e+02
#   Ejecución 7: 1.8300e+02
#   Ejecución 8: 1.6600e+02
#   Ejecución 9: 3.6500e+02
#   Ejecución 10: 1.5800e+02
#
# Ejecutando 10 veces para: Quartic...
#   Ejecución 1: 1.2132e-02
#   Ejecución 2: 1.5737e-02
#   Ejecución 3: 1.7266e-02
#   Ejecución 4: 3.6993e-02
#   Ejecución 5: 1.0271e-02
#   Ejecución 6: 1.1875e-02
#   Ejecución 7: 3.2118e-02
#   Ejecución 8: 1.2142e-02
#   Ejecución 9: 5.1778e-03
#   Ejecución 10: 5.6223e-02
#
# Ejecutando 10 veces para: Schwefel 4...
#   Ejecución 1: -5.6350e+03
#   Ejecución 2: -6.4177e+03
#   Ejecución 3: -6.1544e+03
#   Ejecución 4: -6.7474e+03
#   Ejecución 5: -6.1495e+03
#   Ejecución 6: -6.5369e+03
#   Ejecución 7: -5.3388e+03
#   Ejecución 8: -5.6786e+03
#   Ejecución 9: -6.1241e+03
#   Ejecución 10: -5.9207e+03
#
# Ejecutando 10 veces para: Rastrigin...
#   Ejecución 1: 6.5377e+01
#   Ejecución 2: 6.1909e+01
#   Ejecución 3: 6.9891e+01
#   Ejecución 4: 6.8610e+01
#   Ejecución 5: 4.9656e+01
#   Ejecución 6: 7.4966e+01
#   Ejecución 7: 7.4435e+01
#   Ejecución 8: 6.7409e+01
#   Ejecución 9: 6.9407e+01
#   Ejecución 10: 8.9482e+01
#
# Ejecutando 10 veces para: Ackley...
#   Ejecución 1: 5.9622e+00
#   Ejecución 2: 4.4313e+00
#   Ejecución 3: 5.0019e+00
#   Ejecución 4: 4.8624e+00
#   Ejecución 5: 6.5177e+00
#   Ejecución 6: 5.1453e+00
#   Ejecución 7: 5.9947e+00
